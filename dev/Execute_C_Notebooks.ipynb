# %% [markdown]
# Written by Troels Schwarz-Linnet, December 2018 <br>
# To convert C# code from: https://github.com/ExamRef70-483/Sample-Code.git to Jupyter Notebooks

# %%
import glob
import os
import nbformat as nbf
from nbconvert.preprocessors import ExecutePreprocessor
ep = ExecutePreprocessor(timeout=60, kernel_name='kernel-spec')

files = glob.glob('../Exam_Ref_70-483_Programming_in_C#_2nd_Edition/*/*/*.ipynb', recursive=True)
output_list = [] 
for f in files:
    chapter_nr = f.split('/')[2].split(" ")[1]
    chapter = f.split('/')[2].split(chapter_nr)[1][1:]
    skill_nr = f.split('/')[3].split(" ")[1]
    skill = f.split('/')[3].split(skill_nr)[1][1:]
    title_nr = f.split('/')[4].split(" ")[1]
    title = f.split('/')[4].split(title_nr)[1][1:].replace(".ipynb","")
    if chapter_nr in ["1", "2", "3", "4"]:
        nb = nbf.read(f, as_version=4)

        # Get link to source github
        github_md = nb['cells'][1]['source'].split("\n")[2][2:]
        github_link = github_md.split("(")[1][:-1]
        #print(github_link)
        
        # Test if there is output
        has_output = False
        for cell in nb['cells']:
            if cell['cell_type'] == "code":
                if cell['outputs'] != []:
                    has_output = True

        s = "* C:%s, S:%s, T:%s %s"%(chapter_nr, skill_nr, title_nr, title)
        s2 = "%s : %s"%(s, github_md)
        if has_output:
            print(s)
            output_list.append(s2)
        else:
            try:
                outconv = ep.preprocess(nb, {'metadata': {}})
                nbf.write(nb, f)
                print(s)
                output_list.append(s2)
            except:
                s3 = "* FAILED: %s"%s
                s4 = "%s : %s"%(s3, github_md)
                output_list.append(s4)

wf = open("Execute_C_Notebooks.md", "w")
for l in output_list:
    wf.write(l + "\n")
wf.close()

print("Done")
# Out:
# * C:1, S:1.1, T:1-01 Parallel Invoke
# * C:1, S:1.1, T:1-02 ParallelForEach in use
# * C:1, S:1.1, T:1-03 ParallelFor in use
# * C:1, S:1.1, T:1-04 Managing a parallel For loop
# * C:1, S:1.1, T:1-05 A parallel LINQ query
# * C:1, S:1.1, T:1-06 A informing parallelization
# * C:1, S:1.1, T:1-07 Using AsOrdered
# * C:1, S:1.1, T:1-08 Sequential elements
# * C:1, S:1.1, T:1-09 Using the ForAll method
# * C:1, S:1.1, T:1-10 Exceptions in PLINQ
# * C:1, S:1.1, T:1-11 Create a task
# * C:1, S:1.1, T:1-12 Run a task
# * C:1, S:1.1, T:1-13 Task Factory
# * C:1, S:1.1, T:1-13 Task returning a value
# * C:1, S:1.1, T:1-13 Task waitall
# * C:1, S:1.1, T:1-14 Task waitall
# * C:1, S:1.1, T:1-15 Continuation tasks
# * C:1, S:1.1, T:1-16 Continuation options
# * C:1, S:1.1, T:1-17 Attached child tasks
# * C:1, S:1.1, T:1-18 Creating threads
# * C:1, S:1.1, T:1-19 Using ThreadStart
# * C:1, S:1.1, T:1-21 ParameterizedThreadStart
# * C:1, S:1.1, T:1-22 thread lambda parameters
# * C:1, S:1.1, T:1-23 aborting a thread
# * C:1, S:1.1, T:1-24 shared flag variable
# * C:1, S:1.1, T:1-25 Using join
# * C:1, S:1.1, T:1-26 ThreadLocal
# * C:1, S:1.1, T:1-27 Thread context
# * C:1, S:1.1, T:1-28 Thread pool
# * C:1, S:1.1, T:1-35 Using BlockingCollection
# * C:1, S:1.1, T:1-36 Block ConcurrentStack
# * C:1, S:1.1, T:1-37 Concurrent queue
# * C:1, S:1.1, T:1-38 Concurrent stack
# * C:1, S:1.1, T:1-39 Concurrent bag
# * C:1, S:1.1, T:1-40 Concurrent dictionary
# * C:1, S:1.2, T:1-41 Single task summing
# * C:1, S:1.2, T:1-42 Bad task interaction
# * C:1, S:1.2, T:1-43 Using locking
# * C:1, S:1.2, T:1-44 Sensible locking
# * C:1, S:1.2, T:1-45 Using monitors
# * C:1, S:1.2, T:1-46 Sequential locking
# * C:1, S:1.2, T:1-48 interlock total
# * C:1, S:1.2, T:1-49 cancel a task
# * C:1, S:1.2, T:1-50 cancel with exception
# * C:1, S:1.2, T:1-51 unsafe thread method
# * C:1, S:1.3, T:1-53 do while loops
# * C:1, S:1.3, T:1-54 for loops
# * C:1, S:1.3, T:1-55 iterate with for
# * C:1, S:1.3, T:1-56 iterate with foreach
# * C:1, S:1.3, T:1-57 uppercase Person
# * C:1, S:1.3, T:1-58 using break
# * C:1, S:1.3, T:1-59 using continue
# * C:1, S:1.3, T:1-60 if construction
# * C:1, S:1.3, T:1-61 logical expressions
# * C:1, S:1.3, T:1-62 The switch construction
# * C:1, S:1.3, T:1-64 Expression evaluation
# * C:1, S:1.4, T:1-65 Null conditional
# * C:1, S:1.4, T:1-65 Publish and subscribe
# * C:1, S:1.4, T:1-66 Unsubscribing
# * C:1, S:1.4, T:1-67 Event based alarm
# * C:1, S:1.4, T:1-68 EventHandler alarm
# * C:1, S:1.4, T:1-70 Aggregating exceptions
# * C:1, S:1.4, T:1-71 Create delegates
# * C:1, S:1.4, T:1-72 Lambda expressions
# * C:1, S:1.4, T:1-73 Closures
# * C:1, S:1.4, T:1-74 Built in delegates
# * C:1, S:1.4, T:1-75 lambda expression task
# * C:1, S:1.5, T:1-76 try catch
# * C:1, S:1.5, T:1-77 Exception object
# * C:1, S:1.5, T:1-78 Exception types
# * C:1, S:1.5, T:1-79 The finally block
# * C:1, S:1.5, T:1-83 Inner exceptions
# * C:1, S:1.5, T:1-84 Aggregate exceptions
# * C:2, S:2.1, T:2-01 Value and reference types
# * C:2, S:2.1, T:2-02 Immutable DateTime
# * C:2, S:2.1, T:2-03 Creating a structure
# * C:2, S:2.1, T:2-04 Creating an enum
# * C:2, S:2.1, T:2-05 Creating a reference
# * C:2, S:2.1, T:2-06 Using generic types
# * C:2, S:2.1, T:2-07 Constructors
# * C:2, S:2.1, T:2-08 Overloaded constructors
# * C:2, S:2.1, T:2-09 Calling constructors
# * C:2, S:2.1, T:2-10 Static constructors
# * C:2, S:2.1, T:2-12 Simple method
# * C:2, S:2.1, T:2-13 Extension method
# * C:2, S:2.1, T:2-14 Named parameters
# * C:2, S:2.1, T:2-15 Optional parameters
# * C:2, S:2.1, T:2-16 Indexed properties
# * C:2, S:2.1, T:2-17 Indexing on strings
# * C:2, S:2.1, T:2-18 Overloaded DateTime constructor
# * C:2, S:2.1, T:2-19 Method overriding
# * C:2, S:2.1, T:2-20 Using base
# * C:2, S:2.2, T:2-21 Boxing and unboxing
# * C:2, S:2.2, T:2-23 Type conversion
# * C:2, S:2.2, T:2-25 Using dynamic variables
# * C:2, S:2.2, T:2-26 Interacting with Excel
# * C:2, S:2.3, T:2-27 Public data members
# * C:2, S:2.3, T:2-29 Creating accessor methods
# * C:2, S:2.3, T:2-30 Protected access
# * C:2, S:2.3, T:2-31 Protected class
# * C:2, S:2.3, T:2-32 Printing interface
# * C:2, S:2.4, T:2-33 iPrintable interface
# * C:2, S:2.4, T:2-34 IAccount interface
# * C:2, S:2.4, T:2-35 BabyAccount
# * C:2, S:2.4, T:2-36 Overridden WithdrawFunds
# * C:2, S:2.4, T:2-37 The base method
# * C:2, S:2.4, T:2-38 BankAccount constructor
# * C:2, S:2.4, T:2-39 Comparing bank accounts
# * C:2, S:2.4, T:2-40 Typed IComparable
# * C:2, S:2.4, T:2-41 Get an enumerator
# * C:2, S:2.4, T:2-42 Using foreach
# * C:2, S:2.4, T:2-43 Creating an enumerable type
# * C:2, S:2.4, T:2-44 Using yield
# * C:2, S:2.4, T:2-45 Using IDisposable
# * C:2, S:2.5, T:2-46 The serializable atribute
# * C:2, S:2.5, T:2-46 The serializable attribute
# * C:2, S:2.5, T:2-47 The conditional attribute
# * C:2, S:2.5, T:2-48 Testing for an attribute
# * C:2, S:2.5, T:2-49 Creating an attribute class
# * C:2, S:2.5, T:2-50 Controlling attribute access
# * C:2, S:2.5, T:2-51 Read an attribute
# * C:2, S:2.5, T:2-52 The GetType method
# * C:2, S:2.5, T:2-53 Investigating a type
# * C:2, S:2.5, T:2-54 Reflection method call
# * C:2, S:2.5, T:2-55 Finding components
# * C:2, S:2.5, T:2-56 LINQ components
# * C:2, S:2.5, T:2-57 CodeDOM object
# * C:2, S:2.5, T:2-58 Lambda expression tree
# * C:2, S:2.5, T:2-59 Modifying an expression tree
# * C:2, S:2.5, T:2-60 Assembly object
# * C:2, S:2.5, T:2-61 Property info
# * C:2, S:2.5, T:2-62 Method reflection
